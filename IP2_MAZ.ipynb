# %% [markdown]
# ## 1.

# %%
import pandas as pd

# %%
df1=pd.read_csv("weather_2012.csv")

# %% [markdown]
# ## 2.

# %%
# First five rows
df1.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
# Last five rows
df1.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
# Sample of five random rows
df1.sample(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 4015  2012-06-16 07:00:00      16.2                 9.3           64
# 5276  2012-08-07 20:00:00      25.8                13.7           47
# 1888  2012-03-19 16:00:00      16.6                 9.7           64
# 8531  2012-12-21 11:00:00       0.9                 0.0           94
# 1027  2012-02-12 19:00:00     -11.9               -19.3           54
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 4015               15             48.3           102.25  Mostly Cloudy
# 5276               17             25.0           100.81  Mostly Cloudy
# 1888               11             24.1           101.66   Mainly Clear
# 8531               30              2.0            99.01           Snow
# 1027               24             25.0           100.58  Mostly Cloudy

# %% [markdown]
# ## 3.

# %%
df1.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %% [markdown]
# ## 4.

# %%
df1=df1.rename(columns={"Date/Time":"date_time", "Temp (C)":'temp_c', 
                      "Dew Point Temp (C)":"dew_point", "Rel Hum (%)":"relative_humidity", 
                      "Wind Spd (km/h)": "wind_speed", "Visibility (km)":"visibility", 
                      "Stn Press (kPa)": "pressure", "Weather":"weather"})

# %%
df1.head()
# Out:
#              date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0  2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1  2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2  2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3  2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4  2012-01-01 04:00:00    -1.5       -3.3                 88           7
#
#    visibility  pressure               weather
# 0         8.0    101.24                   Fog
# 1         8.0    101.24                   Fog
# 2         4.0    101.26  Freezing Drizzle,Fog
# 3         4.0    101.27  Freezing Drizzle,Fog
# 4         4.8    101.23                   Fog

# %%
df=df1.copy(deep=True)
df.head()
# Out:
#             date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0 2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1 2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2 2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3 2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4 2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
#
#    wind_speed  visibility  pressure               weather  month
# 0           4         8.0    101.24                   Fog      1
# 1           4         8.0    101.24                   Fog      1
# 2           7         4.0    101.26  Freezing Drizzle,Fog      1
# 3           6         4.0    101.27  Freezing Drizzle,Fog      1
# 4           7         4.8    101.23                   Fog      1

# %% [markdown]
# ## 5.

# %%
df.describe()
# Out:
#             temp_f       temp_c    dew_point  relative_humidity   wind_speed  \
# count  8784.000000  8784.000000  8784.000000        8784.000000  8784.000000
# mean     47.836660     8.798144     2.555294          67.431694    14.945469
# std      21.038189    11.687883    10.883072          16.918881     8.688696
# min      -9.940000   -23.300000   -28.500000          18.000000     0.000000
# 25%      32.180000     0.100000    -5.900000          56.000000     9.000000
# 50%      48.740000     9.300000     3.300000          68.000000    13.000000
# 75%      65.840000    18.800000    11.800000          81.000000    20.000000
# max      91.400000    33.000000    24.400000         100.000000    83.000000
#
#         visibility     pressure        month
# count  8784.000000  8784.000000  8784.000000
# mean     27.664447   101.051623     6.513661
# std      12.622688     0.844005     3.451430
# min       0.200000    97.520000     1.000000
# 25%      24.100000   100.560000     4.000000
# ...

# %% [markdown]
# ## 6.

# %%
df['temp_f']=df['temp_c']*9/5+32

# %%
df
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0    2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1    2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2    2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3    2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4    2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
# ...                  ...     ...     ...        ...                ...
# 8779 2012-12-31 19:00:00   32.18     0.1       -2.7                 81
# 8780 2012-12-31 20:00:00   32.36     0.2       -2.4                 83
# 8781 2012-12-31 21:00:00   31.10    -0.5       -1.5                 93
# 8782 2012-12-31 22:00:00   31.64    -0.2       -1.8                 89
# 8783 2012-12-31 23:00:00   32.00     0.0       -2.1                 86
#
#       wind_speed  visibility  pressure               weather  month
# ...

# %% [markdown]
# ## 7. Write the code to rearrange the columns in the dataset so temp_f appears immediately before temp_c.

# %%
df=df[['date_time', 'temp_f', 'temp_c', 'dew_point', 'relative_humidity', 'wind_speed', 'visibility', 'pressure', 'weather']]

# %%
df
# Out:
#                 date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0     2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1     2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2     2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3     2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4     2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
# ...                   ...     ...     ...        ...                ...
# 8779  2012-12-31 19:00:00   32.18     0.1       -2.7                 81
# 8780  2012-12-31 20:00:00   32.36     0.2       -2.4                 83
# 8781  2012-12-31 21:00:00   31.10    -0.5       -1.5                 93
# 8782  2012-12-31 22:00:00   31.64    -0.2       -1.8                 89
# 8783  2012-12-31 23:00:00   32.00     0.0       -2.1                 86
#
#       wind_speed  visibility  pressure               weather
# ...

# %% [markdown]
# ## 8.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          8784 non-null   object
#  1   temp_f             8784 non-null   float64
#  2   temp_c             8784 non-null   float64
#  3   dew_point          8784 non-null   float64
#  4   relative_humidity  8784 non-null   int64
#  5   wind_speed         8784 non-null   int64
#  6   visibility         8784 non-null   float64
#  7   pressure           8784 non-null   float64
#  8   weather            8784 non-null   object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 617.8+ KB

# %% [markdown]
# ## 9.

# %%
df['date_time']=pd.to_datetime(df['date_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          8784 non-null   datetime64[ns]
#  1   temp_f             8784 non-null   float64
#  2   temp_c             8784 non-null   float64
#  3   dew_point          8784 non-null   float64
#  4   relative_humidity  8784 non-null   int64
#  5   wind_speed         8784 non-null   int64
#  6   visibility         8784 non-null   float64
#  7   pressure           8784 non-null   float64
#  8   weather            8784 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 617.8+ KB

# %% [markdown]
# ## 10.

# %%
df.columns
# Out:
# Index(['date_time', 'temp_f', 'temp_c', 'dew_point', 'relative_humidity',
#        'wind_speed', 'visibility', 'pressure', 'weather'],
#       dtype='object')

# %%
df['weather'].value_counts()[0:10]
# Out:
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Rain              306
# Rain Showers      188
# Fog               150
# Rain,Fog          116
# Drizzle,Fog        80
# Name: weather, dtype: int64

# %% [markdown]
# ## 11.

# %%
df.columns
# Out:
# Index(['date_time', 'temp_f', 'temp_c', 'dew_point', 'relative_humidity',
#        'wind_speed', 'visibility', 'pressure', 'weather', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#             date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0 2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1 2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2 2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3 2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4 2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
#
#    wind_speed  visibility  pressure               weather  month
# 0           4         8.0    101.24                   Fog      1
# 1           4         8.0    101.24                   Fog      1
# 2           7         4.0    101.26  Freezing Drizzle,Fog      1
# 3           6         4.0    101.27  Freezing Drizzle,Fog      1
# 4           7         4.8    101.23                   Fog      1

# %%
df.query('temp_f>90 & relative_humidity<50 & dew_point>17 & weather=="Clear"')
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 5199 2012-08-04 15:00:00   91.04    32.8       18.8                 44
# 5200 2012-08-04 16:00:00   90.50    32.5       18.5                 44
# 5201 2012-08-04 17:00:00   90.50    32.5       19.8                 47
#
#       wind_speed  visibility  pressure weather  month
# 5199          17        24.1    101.39   Clear      8
# 5200          15        24.1    101.34   Clear      8
# 5201          13        24.1    101.32   Clear      8

# %%
df_new=df.query('temp_f>90 & relative_humidity<50 & dew_point>17 & weather=="Clear"')

# %%
df_new.head()
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 5199 2012-08-04 15:00:00   91.04    32.8       18.8                 44
# 5200 2012-08-04 16:00:00   90.50    32.5       18.5                 44
# 5201 2012-08-04 17:00:00   90.50    32.5       19.8                 47
#
#       wind_speed  visibility  pressure weather  month
# 5199          17        24.1    101.39   Clear      8
# 5200          15        24.1    101.34   Clear      8
# 5201          13        24.1    101.32   Clear      8

# %%
df_new.columns
# Out:
# Index(['date_time', 'temp_f', 'temp_c', 'dew_point', 'relative_humidity',
#        'wind_speed', 'visibility', 'pressure', 'weather', 'month'],
#       dtype='object')

# %% [markdown]
# ## 12.

# %%
df_new['month']=pd.to_datetime(df_new['date_time']).dt.month
# Out:
# /var/folders/s0/__n7qh094kn1cmctf_bzlhmc0000gn/T/ipykernel_43476/2218691963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['month']=pd.to_datetime(df_new['date_time']).dt.month

# %%
df_new.head()
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 5199 2012-08-04 15:00:00   91.04    32.8       18.8                 44
# 5200 2012-08-04 16:00:00   90.50    32.5       18.5                 44
# 5201 2012-08-04 17:00:00   90.50    32.5       19.8                 47
#
#       wind_speed  visibility  pressure weather  month
# 5199          17        24.1    101.39   Clear      8
# 5200          15        24.1    101.34   Clear      8
# 5201          13        24.1    101.32   Clear      8

# %% [markdown]
# ## 13.

# %%
df_new.to_csv('weather_2012_new.csv', index=False)

# %%
df_new=pd.read_csv('weather_2012_new.csv', index_col=[0])
df_new.sample(2)
# Out:
#                      temp_f  temp_c  dew_point  relative_humidity  wind_speed  \
# date_time
# 2012-08-04 17:00:00   90.50    32.5       19.8                 47          13
# 2012-08-04 15:00:00   91.04    32.8       18.8                 44          17
#
#                      visibility  pressure weather  month
# date_time
# 2012-08-04 17:00:00        24.1    101.32   Clear      8
# 2012-08-04 15:00:00        24.1    101.39   Clear      8
